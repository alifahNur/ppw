# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import skipgrams
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Reshape
from tensorflow.keras.optimizers import Adam

# %%
# 1. Persiapan data (contoh sederhana)
text = "anjing suka makan tulang kucing suka makan ikan burung terbang tinggi"

# %%
# Tokenisasi teks
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
word2idx = tokenizer.word_index
idx2word = {v: k for k, v in word2idx.items()}
vocab_size = len(word2idx) + 1  # +1 untuk padding

# %%
# Konversi teks ke urutan token
sequences = tokenizer.texts_to_sequences([text])[0]

# %%
# 2. Membuat pasangan Skip-gram (kata target, konteks)
pairs, labels = skipgrams(sequences, vocab_size, window_size=2)

# %%
# 3. Membuat Model Skip-Gram
embedding_dim = 3  # Vektor embedding 3 dimensi

# %%
# Model Sequential
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=1))
model.add(Reshape((embedding_dim,)))  # Mengubah output embedding jadi vektor
model.add(Dense(vocab_size, activation='softmax'))  # Output adalah prediksi konteks

# %%
# Kompilasi model
model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# %%
# 4. Menyiapkan data untuk pelatihan
target_words = np.array([pair[0] for pair in pairs])
context_words = np.array([pair[1] for pair in pairs])

# %%
# Latih model
model.fit(target_words, context_words, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.1990 - loss: 2.3003
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1990 - loss: 2.2998
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2107 - loss: 2.2977
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1990 - loss: 2.2954
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2212 - loss: 2.2939
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2500 - loss: 2.2925
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2695 - loss: 2.2910
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2122 - loss: 2.2923
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2200 - loss: 2.2885
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2395 - loss: 2.2878
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2239 - loss: 2.2850
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2383 - loss: 2.2855
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2461 - loss: 2.2869
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2512 - loss: 2.2818
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2512 - loss: 2.2795
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2356 - loss: 2.2809
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2356 - loss: 2.2783
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2395 - loss: 2.2762
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2161 - loss: 2.2761
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2317 - loss: 2.2737
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2200 - loss: 2.2756
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2461 - loss: 2.2681
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2566 - loss: 2.2705
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2566 - loss: 2.2679
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2839 - loss: 2.2637
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2410 - loss: 2.2629
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2722 - loss: 2.2590
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2410 - loss: 2.2649
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2449 - loss: 2.2647
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2605 - loss: 2.2623
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2800 - loss: 2.2574
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2488 - loss: 2.2550
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2292 - loss: 2.2611
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2644 - loss: 2.2533
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2644 - loss: 2.2540
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2956 - loss: 2.2470
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2605 - loss: 2.2480
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2292 - loss: 2.2503
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2956 - loss: 2.2402
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2878 - loss: 2.2425
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2878 - loss: 2.2341
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2761 - loss: 2.2388
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2878 - loss: 2.2347
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2644 - loss: 2.2382
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2683 - loss: 2.2365
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2566 - loss: 2.2361
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2722 - loss: 2.2334
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2722 - loss: 2.2271
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2527 - loss: 2.2311
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2566 - loss: 2.2301
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2605 - loss: 2.2276
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2214 - loss: 2.2308
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2761 - loss: 2.2203
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2644 - loss: 2.2248
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2331 - loss: 2.2268
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2527 - loss: 2.2218
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2175 - loss: 2.2263
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2683 - loss: 2.2127
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2995 - loss: 2.2066
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2644 - loss: 2.2104
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2566 - loss: 2.2125
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2605 - loss: 2.2074
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2566 - loss: 2.2080
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2722 - loss: 2.2062
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2527 - loss: 2.2055
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2956 - loss: 2.2021
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2995 - loss: 2.1913
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2683 - loss: 2.1960
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2722 - loss: 2.1921
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2878 - loss: 2.1934
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2527 - loss: 2.2057
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2593 - loss: 2.1972
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2827 - loss: 2.1856
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2983 - loss: 2.1761
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3061 - loss: 2.1840
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3061 - loss: 2.1705
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2710 - loss: 2.1908
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2710 - loss: 2.1912
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3061 - loss: 2.1684
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2866 - loss: 2.1780
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2593 - loss: 2.1860
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2671 - loss: 2.1930
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2905 - loss: 2.1645
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2827 - loss: 2.1771
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2788 - loss: 2.1741
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2788 - loss: 2.1734
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2944 - loss: 2.1551
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2788 - loss: 2.1771
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2514 - loss: 2.1649
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2788 - loss: 2.1593
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2436 - loss: 2.1667
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2749 - loss: 2.1569
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2983 - loss: 2.1534
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2749 - loss: 2.1631
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2593 - loss: 2.1536
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2983 - loss: 2.1490
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3139 - loss: 2.1438
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2632 - loss: 2.1551
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2788 - loss: 2.1546
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3218 - loss: 2.1341

# %%
# 5. Lihat hasil embedding (vektor representasi kata)
embeddings = model.layers[0].get_weights()[0]

# %%
# Tampilkan vektor embedding untuk setiap kata
for word, i in word2idx.items():
    print(f"Vektor embedding untuk kata '{word}': {embeddings[i]}")
# Out:
# Vektor embedding untuk kata 'suka': [ 0.23315194  0.09371545 -0.3457369 ]
# Vektor embedding untuk kata 'makan': [-0.27384168  0.05476398 -0.18892683]
# Vektor embedding untuk kata 'anjing': [-0.13610274  0.03547959 -0.04224649]
# Vektor embedding untuk kata 'tulang': [-0.15617885  0.01009094  0.06623537]
# Vektor embedding untuk kata 'kucing': [ 0.16151963  0.26851556 -0.31127104]
# Vektor embedding untuk kata 'ikan': [-0.11812352  0.10711876 -0.08763087]
# Vektor embedding untuk kata 'burung': [ 0.22587049 -0.2147045   0.12769897]
# Vektor embedding untuk kata 'terbang': [-0.19039162 -0.3829218   0.00814358]
# Vektor embedding untuk kata 'tinggi': [-0.06208886 -0.27154014 -0.12983596]
